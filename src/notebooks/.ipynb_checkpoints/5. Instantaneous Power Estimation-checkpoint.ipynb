# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#pd.set_option("display.max_rows", 1000)
pd.set_option("display.max_columns", 100)

# %%
file_paths = {'in':'../../data/cleaned/activities/4439566437.csv'
             }

df = pd.read_csv(file_paths['in'])

# guarantee the timestamps are datetime objects
df['time'] = pd.to_datetime(df['time'])

# %%
if 'index' in df.columns:
    df.drop(['index'], axis=1, inplace=True)

# %%
df.head()
# Out:
#                        time       ride_id  segment_id  elevation   latitude  \
# 0 2020-12-06 18:36:38+00:00  4.439566e+09         0.0   884.8857  40.067950
# 1 2020-12-06 18:36:39+00:00  4.439566e+09         0.0   884.8857  40.067975
# 2 2020-12-06 18:36:40+00:00  4.439566e+09         0.0   884.8857  40.067999
# 3 2020-12-06 18:36:41+00:00  4.439566e+09         0.0   884.8857  40.068021
# 4 2020-12-06 18:36:42+00:00  4.439566e+09         0.0   884.8857  40.068023
#
#    longitude  elapsed_time  delta_time  moving_time  delta_dist     heading  \
# 0 -83.127786           1.0         1.0          1.0         NaN         NaN
# 1 -83.127779           2.0         1.0          2.0    0.001739   72.979474
# 2 -83.127771           3.0         1.0          3.0    0.001739   72.979474
# 3 -83.127801           4.0         1.0          4.0    0.002197  143.746162
# 4 -83.127808           5.0         1.0          5.0    0.000395  164.054604
#
#       speed  is_cruising  grade  elapsed_ascent  elapsed_descent  \
# 0  6.259034        False    0.0             0.0              0.0
# 1  6.259034        False    0.0             0.0              0.0
# 2  6.259034        False    0.0             0.0              0.0
# 3  7.909226        False    0.0             0.0              0.0
# 4  1.422308        False    0.0             0.0              0.0
#
#    elapsed_elevation  training_window_id  filt_speed  filt_grade
# 0                0.0                   6    3.172414         0.0
# 1                0.0                   6    4.504257         0.0
# 2                0.0                   6    5.225672         0.0
# 3                0.0                   6    5.034892         0.0
# 4                0.0                   6    4.021185         0.0

# %% [markdown]
# ### Grab Segment 22 as the longest representative segment

# %%
df22 = df.loc[df['segment_id']==22,:].reset_index()

# %% [markdown]
# ### Acquire the Bike Weight from Activity Log

# %%
df.loc[0,'ride_id']
# Out:
# 4439566437.0

# %%
ride_id = 4439566437

# %%
df_log = pd.read_csv('../../data/cleaned/activity_log.csv')

# %%
df_log = df_log.set_index('ride_id')
bike_weight = df_log.loc[ride_id, 'bike_weight']
print(f'bike weighs {bike_weight} kg')
# Out:
# bike weighs 15.8757 kg

# %% [markdown]
# # 1. Define Power Calculation Parameters

# %%
params = {'total_mass': bike_weight + 86.1826, # kg
          'area': 0.4635862, # m^2
          'mu_rr': 0.005, # coefficient of rolling friction
          'c_drag': 0.95, # coefficient of drag
          'rho_air': 1.2, # kg/m^3 air density
          'eta_dt': 0.96, # efficiency of drive train
          'gravity': 9.8 # m/s^2
         }

# %% [markdown]
# # 2. Convert the Imperial Columns to Metric
# Also convert the grade into an angle

# %%
df22['filt_grade_radians'] = np.arctan(df22['filt_grade']/100)

# %%
mph2MpS = 0.44704 # 1 MPH = 0.44704 m/s
df22['filt_speed_MpS'] = mph2MpS * df22['filt_speed']

# %% [markdown]
# # 3. Compute the Forces Resisting Motion

# %%
params['total_mass']*params['gravity']
# Out:
# 1000.17134

# %%
df22['F_grav'] = params['total_mass']*params['gravity'] * np.sin(df22['filt_grade_radians'])

# %%
df22['F_fric'] = params['mu_rr']*params['total_mass']*params['gravity'] * np.cos(df22['filt_grade_radians'])

# %%
def get_wind_velocity_component(df, df_log):
    # TODO: add in weather data and a cosine between wind bearing and bike heading to project the contribution of wind
    # onto the direction of motion
    df = df.copy()
    df['wind_velocity_component'] = 0 # constant zero for now
    return df

# %%
df22 = get_wind_velocity_component(df22, df_log)

# %%
full_coefficient = 0.5 * params['rho_air'] * params['area'] * params['c_drag']
df22['F_drag'] = (full_coefficient) * np.power(df22['filt_speed_MpS']+df22['wind_velocity_component'], 2) # k*(v+wind)^2

# %%
df22['F_sum'] = df22['F_drag'] + df22['F_grav'] + df22['F_fric']

# %%
# visualize the jumps of cumulative time 
fig = plt.figure(figsize=(15,8))

_ = sns.lineplot(x='elapsed_time', y='F_drag', data=df22, color='g', label='Drag')
_ = sns.lineplot(x='elapsed_time', y='F_fric', data=df22, color='r', label='Friction')
_ = sns.lineplot(x='elapsed_time', y='F_grav', data=df22, color='b', label='Gravity')
_ = sns.lineplot(x='elapsed_time', y='F_sum', data=df22, color='k', label='TOTAL')

_ = plt.xlabel('Elapsed Time (seconds)', fontsize=16)
_ = plt.ylabel('Force (N)', fontsize=16)
_ = plt.title('Bike Ride Forces vs. Time', fontsize=20)
_ = plt.grid()
_ = plt.xlim([6000, 7000])

# %%
# visualize the jumps of cumulative time 
fig = plt.figure(figsize=(15,4))

_ = sns.lineplot(x='elapsed_time', y='filt_speed', data=df22, color='magenta', label='Drag')

_ = plt.xlabel('Elapsed Time (seconds)', fontsize=16)
_ = plt.ylabel('Speed (MPH)', fontsize=16)
_ = plt.title('Bike Ride Speed vs. Time', fontsize=20)
_ = plt.grid()
_ = plt.xlim([6000, 7000])

# %%
# visualize the jumps of cumulative time 
fig = plt.figure(figsize=(15,4))

_ = sns.lineplot(x='elapsed_time', y='filt_grade', data=df22, color='purple', label='Drag')

_ = plt.xlabel('Elapsed Time (seconds)', fontsize=16)
_ = plt.ylabel('Grade %', fontsize=16)
_ = plt.title('Bike Ride Grade vs. Time', fontsize=20)
_ = plt.grid()
_ = plt.xlim([6000, 7000])

# %% [markdown]
# # 4. Computing My Instantaneous Power
# Assume that when `F_sum` <0 that I always coast.

# %%
df22['inst_power'] = (1.0/params['eta_dt']) * df22['F_sum'] * df22['filt_speed_MpS'] 
df22.loc[df22['inst_power']<0,'inst_power'] = 0 # coasting when sum of forces is negative (no input power)

# %%
# visualize the jumps of cumulative time 
fig = plt.figure(figsize=(15,6))

_ = sns.lineplot(x='elapsed_time', y='inst_power', data=df22, color='blue', label='Power')

_ = plt.xlabel('Elapsed Time (seconds)', fontsize=16)
_ = plt.ylabel('Instantaneous Power (W)', fontsize=16)
_ = plt.title('Bike Ride Power vs. Time', fontsize=20)
_ = plt.grid()
#_ = plt.xlim([6000, 7000])

# %%
np.mean(df22['inst_power'])
# Out:
# 124.03833034935393

# %%
def get_instantaneous_power(df, params):
    df = df.copy()
    cols_to_drop_later = ['filt_grade_radians','filt_speed_MpS','F_grav','F_fric','F_drag', 'F_sum', 
                         'total_speed', 'wind_velocity_component']
    
    # Convert the terrain slope into radians
    df['filt_grade_radians'] = np.arctan(df['filt_grade']/100)
    
    # Convert the speed units into meters per second
    mph2MpS = 0.44704 # 1 MPH = 0.44704 m/s
    df['filt_speed_MpS'] = mph2MpS * df['filt_speed']
    
    # Get the total speed component with wind (placeholder)
    df = get_wind_velocity_component(df, None)
    df['total_speed'] = df['filt_speed_MpS'] + df['wind_velocity_component']
    
    # Calculate the individual forces
    df['F_grav'] = params['total_mass']*params['gravity'] * np.sin(df['filt_grade_radians'])
    df['F_fric'] = params['mu_rr']*params['total_mass']*params['gravity'] * np.cos(df['filt_grade_radians'])
    full_coefficient = 0.5 * params['rho_air'] * params['area'] * params['c_drag']
    df['F_drag'] = (full_coefficient) * np.power(df['total_speed'], 2) # k(v)^2
    
    # Sum the forces
    df['F_sum'] = df['F_drag'] + df['F_grav'] + df['F_fric']
    
    # Calculate the non-negative power delivered by the ride (set Power=0 for F_sum <0)
    df['inst_power'] = (1.0/params['eta_dt']) * df['F_sum'] * df['filt_speed_MpS'] 
    df.loc[df['inst_power']<0,'inst_power'] = 0 # coasting when sum of forces is negative (no input power)
    
    return df
    

def get_wind_velocity_component(df, df_log):
    # TODO: add in weather data and a cosine between wind bearing and bike heading to project the contribution of wind
    # onto the direction of motion
    df = df.copy()
    df['wind_velocity_component'] = 0 # constant zero for now
    return df

# %%
df = get_instantaneous_power(df=df, params=params)

# %%
# visualize the jumps of cumulative time 
fig = plt.figure(figsize=(15,6))

_ = sns.lineplot(x='elapsed_time', y='inst_power', data=df, color='blue', label='Power')
avg_power = np.mean(df['inst_power']) 
_ = plt.axhline(avg_power, color='r', linestyle='--')

_ = plt.xlabel('Elapsed Time (seconds)', fontsize=16)
_ = plt.ylabel('Instantaneous Power (W)', fontsize=16)
_ = plt.title('Bike Ride Power vs. Time', fontsize=20)
_ = plt.grid()
#_ = plt.xlim([6000, 7000])

# %%
avg_power
# Out:
# 106.50571309574859

# %% [markdown]
# ### Strava's Estimate for this same ride was 101 Watts!!!!

# %%
df
# Out:
#                           time       ride_id  segment_id  elevation  \
# 0    2020-12-06 18:36:38+00:00  4.439566e+09         0.0   884.8857
# 1    2020-12-06 18:36:39+00:00  4.439566e+09         0.0   884.8857
# 2    2020-12-06 18:36:40+00:00  4.439566e+09         0.0   884.8857
# 3    2020-12-06 18:36:41+00:00  4.439566e+09         0.0   884.8857
# 4    2020-12-06 18:36:42+00:00  4.439566e+09         0.0   884.8857
# ...                        ...           ...         ...        ...
# 7008 2020-12-06 20:51:42+00:00  4.439566e+09        23.0   884.8857
# 7009 2020-12-06 20:51:43+00:00  4.439566e+09        23.0   884.8857
# 7010 2020-12-06 20:51:44+00:00  4.439566e+09        23.0   884.8857
# 7011 2020-12-06 20:51:45+00:00  4.439566e+09        23.0   884.8857
# 7012 2020-12-06 20:51:46+00:00  4.439566e+09        23.0   884.8857
#
#        latitude  longitude  elapsed_time  delta_time  moving_time  delta_dist  \
# 0     40.067950 -83.127786           1.0         1.0          1.0         NaN
# 1     40.067975 -83.127779           2.0         1.0          2.0    0.001739
# 2     40.067999 -83.127771           3.0         1.0          3.0    0.001739
# 3     40.068021 -83.127801           4.0         1.0          4.0    0.002197
# 4     40.068023 -83.127808           5.0         1.0          5.0    0.000395
# ...         ...        ...           ...         ...          ...         ...
# 7008  40.067881 -83.127783        8105.0         1.0       7009.0    0.000141
# 7009  40.067882 -83.127783        8106.0         1.0       7010.0    0.000074
# 7010  40.067883 -83.127784        8107.0         1.0       7011.0    0.000074
# 7011  40.067885 -83.127786        8108.0         1.0       7012.0    0.000131
# 7012  40.067886 -83.127787        8109.0         1.0       7013.0    0.000131
#
#          heading     speed  is_cruising  grade  elapsed_ascent  \
# 0            NaN  6.259034        False    0.0          0.0000
# 1      72.979474  6.259034        False    0.0          0.0000
# 2      72.979474  6.259034        False    0.0          0.0000
# 3     143.746162  7.909226        False    0.0          0.0000
# 4     164.054604  1.422308        False    0.0          0.0000
# ...          ...       ...          ...    ...             ...
# 7008  104.036243  0.506495        False    0.0        727.0696
# 7009  116.565051  0.266324        False    0.0        727.0696
# 7010  116.565052  0.266324        False    0.0        727.0696
# 7011  135.000000  0.469824        False    0.0        727.0696
# 7012  135.000000  0.469824        False    0.0        727.0696
#
#       elapsed_descent  elapsed_elevation  training_window_id  filt_speed  \
# 0              0.0000             0.0000                   6    3.172414
# 1              0.0000             0.0000                   6    4.504257
# 2              0.0000             0.0000                   6    5.225672
# 3              0.0000             0.0000                   6    5.034892
# 4              0.0000             0.0000                   6    4.021185
# ...               ...                ...                 ...         ...
# 7008         727.0696          1454.1392                   6    0.543938
# 7009         727.0696          1454.1392                   6    0.443969
# 7010         727.0696          1454.1392                   6    0.386557
# 7011         727.0696          1454.1392                   6    0.341018
# 7012         727.0696          1454.1392                   6    0.284521
#
#       filt_grade  filt_grade_radians  filt_speed_MpS  wind_velocity_component  \
# 0            0.0                 0.0        1.418196                        0
# 1            0.0                 0.0        2.013583                        0
# 2            0.0                 0.0        2.336084                        0
# 3            0.0                 0.0        2.250798                        0
# 4            0.0                 0.0        1.797630                        0
# ...          ...                 ...             ...                      ...
# 7008         0.0                 0.0        0.243162                        0
# 7009         0.0                 0.0        0.198472                        0
# 7010         0.0                 0.0        0.172807                        0
# 7011         0.0                 0.0        0.152449                        0
# 7012         0.0                 0.0        0.127192                        0
#
#       total_speed  F_grav    F_fric    F_drag     F_sum  inst_power
# 0        1.418196     0.0  5.000857  0.531469  5.532325    8.172834
# 1        2.013583     0.0  5.000857  1.071382  6.072239   12.736414
# 2        2.336084     0.0  5.000857  1.442057  6.442913   15.678322
# 3        2.250798     0.0  5.000857  1.338685  6.339542   14.863570
# 4        1.797630     0.0  5.000857  0.853898  5.854755   10.963215
# ...           ...     ...       ...       ...       ...         ...
# 7008     0.243162     0.0  5.000857  0.015624  5.016481    1.270644
# 7009     0.198472     0.0  5.000857  0.010409  5.011266    1.036037
# 7010     0.172807     0.0  5.000857  0.007891  5.008748    0.901609
# 7011     0.152449     0.0  5.000857  0.006141  5.006998    0.795115
# 7012     0.127192     0.0  5.000857  0.004275  5.005132    0.663139
#
# [7013 rows x 29 columns]
