# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_rows", 1000)
pd.set_option("display.max_columns", 100)

# %%
file_paths = {'in':'../../../data/prepared/activity_log_prepared.csv',
              'out':'../../../data/prepared/activity_log_prepared.csv'
             }

df = pd.read_csv(file_paths['in'])

# guarantee the timestamps are datetime objects
time_columns = ['start_time','end_time','ride_date']

for time_col in time_columns:
    df[time_col] = pd.to_datetime(df[time_col])

# %%
df.head()
# Out:
#       ride_id  row_count  segment_count           ride_date  \
# 0  2975587283       1352              5 2020-01-02 14:02:00
# 1  2992935347       1426              5 2020-01-08 13:20:00
# 2  2994399692       1423              7 2020-01-08 22:08:00
# 3  3248077156       2580              5 2020-04-02 21:38:00
# 4  3255473930       6416             12 2020-04-04 17:23:00
#
#                  start_time                  end_time  elapsed_time  \
# 0 2020-01-02 14:02:58+00:00 2020-01-02 14:29:32+00:00          1642
# 1 2020-01-08 13:20:26+00:00 2020-01-08 13:49:06+00:00          1728
# 2 2020-01-08 22:08:17+00:00 2020-01-08 22:35:04+00:00          1608
# 3 2020-04-02 21:38:02+00:00 2020-04-02 23:03:45+00:00          5143
# 4 2020-04-04 17:23:43+00:00 2020-04-04 19:59:16+00:00          9348
#
#    ride_elapsed_time  moving_time  ride_moving_time   distance  \
# 0               1595         1411              1352   5.275440
# 1               1721         1472              1426   5.231944
# ...

# %%
df.shape
# Out:
# (223, 31)

# %% [markdown]
# # 1. Time Column Investigations

# %%
def compare_columns(df, comparison_title, strava_col, my_etl_col, plotsize=8):
    fig = plt.figure(figsize=(plotsize,plotsize))

    _ = sns.scatterplot(x=strava_col, y=my_etl_col, data=df, s=50, alpha=0.6)
    _ = plt.grid()
    _ = plt.title(comparison_title, fontsize=20)
    _ = plt.xlabel('Strava', fontsize=16)
    _ = plt.ylabel('My ETL', fontsize=16)

# %%
compare_columns(df, 'Elapsed Time Comparison', strava_col='elapsed_time', my_etl_col='ride_elapsed_time')

# %%
compare_columns(df, 'Moving Time Comparison', strava_col='moving_time', my_etl_col='ride_moving_time')

# %% [markdown]
# # 2. Distance Comparisons

# %%
compare_columns(df, 'Elapsed Distance Comparison', strava_col='distance', my_etl_col='elapsed_distance')

# %% [markdown]
# # 3. Elevation Comparisons

# %%
compare_columns(df, 'Elapsed Ascent Comparison', strava_col='elevation_gain', my_etl_col='elapsed_ascent')

# %%
compare_columns(df, 'Elapsed Descent Comparison', strava_col='elevation_loss', my_etl_col='elapsed_descent')

# %% [markdown]
# # 4. Speed Comparisons

# %%
compare_columns(df, 'Average Speed Comparison', strava_col='avg_speed', my_etl_col='ride_avg_speed')

# %%
compare_columns(df, 'Cruise Speed Comparison', strava_col='avg_speed', my_etl_col='ride_cruise_speed')

# %%
compare_columns(df, 'Max Speed Comparison', strava_col='max_speed', my_etl_col='ride_max_speed')
_ = plt.ylim([0,120])
_ = plt.xlim([0,120])

# %% [markdown]
# # Power Comparison

# %%
compare_columns(df, 'Average Power Comparison', strava_col='avg_power', my_etl_col='ride_avg_power')
_ = plt.ylim([0,500])
# QUITE A FEW OUTLIERS

# %%
#df.drop(['avg_power'], axis=1, inplace=True)
#df.rename(columns={'ride_avg_power':'avg_power'}, inplace=True)

# %% [markdown]
# # Drop Redudant Columns

# %%
# Drop ride_date since it doesn't contain the richest information compared to start_time
df.drop(['ride_date'], axis=1, inplace=True)

# %%
df.drop(['ride_moving_time'], axis=1, inplace=True)
df.drop(['ride_elapsed_time'], axis=1, inplace=True)

# %%
df.drop(['distance'], axis=1, inplace=True)

# %%
df.drop(['elevation_loss'], axis=1, inplace=True)
df.drop(['elevation_gain'], axis=1, inplace=True)
# Drop elapsed_elevation since it doesn't contain useful information
df.drop(['elapsed_elevation'], axis=1, inplace=True)

# %%
df.drop(['avg_speed'], axis=1, inplace=True)
df.rename(columns={'ride_avg_speed':'avg_speed'}, inplace=True)

# %%
# Based on the comparison, this seemed outlier prone
df.drop(['ride_max_speed'], axis=1, inplace=True)

# %% [markdown]
# # Power Outlier Investigation

# %%
df_temp = df[['ride_id', 'avg_power', 'ride_avg_power']].copy()

# %%
df_temp
# Out:
#         ride_id   avg_power  ride_avg_power
# 0    2975587283         NaN      116.870855
# 1    2992935347         NaN      122.304555
# 2    2994399692         NaN      113.161863
# 3    3248077156         NaN      402.495491
# 4    3255473930         NaN     2104.760010
# 5    3286667096         NaN       78.956781
# 6    3290080609         NaN       69.976203
# 7    3294902966         NaN       79.152945
# 8    3299844988         NaN      102.301107
# 9    3309212141         NaN      101.118739
# 10   3311386012         NaN       76.954649
# 11   3318357988         NaN       63.863914
# 12   3323709534         NaN       92.708908
# 13   3328174429         NaN      122.305078
# 14   3338503991         NaN       97.312920
# 15   3367398159   95.974930       91.116677
# 16   3371564928   92.592812       96.993258
# 17   3381861723   90.597031       95.870437
# 18   3387969771   83.182205       96.662839
# 19   3392547429   89.103729       96.499567
# ...

# %% [markdown]
# ### Ride ID Investigations
#
# **No Strava Estimates**:
# - https://www.strava.com/activities/3248077156 has P = 402 Watts. Refit using median
# - https://www.strava.com/activities/3255473930 has P = 2104 Watts. Refit using median
#
# **Has Strava Estimates (>170 Watts)**:
# - https://www.strava.com/activities/3505140940 had P = 193 Watts. Use Strava Estimate
# - https://www.strava.com/activities/3845870049 had P = 405 Watts. Use Strava Estimate
# - https://www.strava.com/activities/3854038503 had P = 501 Watts. Location data is somewhat bad... Use Strava Estimate
# - https://www.strava.com/activities/3856128927 had P = 837 Watts. Location data is bad **DROP**
# - https://www.strava.com/activities/3873464261 had P = 65 kiloWatts (lol). Use Strava Estimate
# - https://www.strava.com/activities/3902986200 had P = 65546 Watts. Location data is bad **DROP**
# - https://www.strava.com/activities/3938300771 had P = 11 kiloWatts (lol). Location data is somewhat bad... Use Strava Estimate
# - https://www.strava.com/activities/3956271614 had P = 658 Watts. Use Strava Estimate
# - https://www.strava.com/activities/3964264713 had P = 278 Watts. Location data is bad **DROP**
# - https://www.strava.com/activities/4120059933 had P = 2480 Watts. Location data is somewhat bad... Use Strava Estimate
# - https://www.strava.com/activities/5082384851 had P = 221 Watts. Flagged activity since I forgot to stop recording before hopping in car. **DROP**
# - https://www.strava.com/activities/5204597211 had P = 21 Watts. This was a mountain biking adventure. **DROP**

# %%
# Dropping the bad rides
rides_to_drop = [3856128927, 3902986200, 3964264713 , 5082384851, 5204597211]

df = df.set_index('ride_id').drop(index=rides_to_drop).reset_index()

# %%
median_power = df['ride_avg_power'].median()
median_power
# Out:
# 100.59102775

# %%
# replace outliers with null values
filt_power_outlier = df.loc[:,'ride_avg_power'] >= 170 # Watts
df.loc[filt_power_outlier, 'ride_avg_power'] = np.nan

# %%
# fill in missing values
for row_i in range(df.shape[0]):
    if np.isnan(df.loc[row_i, 'ride_avg_power']):
        if np.isnan(df.loc[row_i, 'avg_power']):
            # if the Strava estimate is unavailable, use the median Power
            df.loc[row_i, 'ride_avg_power'] = median_power
        else:
            # Otherwise fill in the Strava estimate
            df.loc[row_i, 'ride_avg_power'] = df.loc[row_i, 'avg_power']

# %%
compare_columns(df, 'Average Power Comparison', strava_col='avg_power', my_etl_col='ride_avg_power')
_ = plt.xlim([0,170])
_ = plt.ylim([0,170])

# %%
# Plot the Distributions of Average Powers for Strava
fig = plt.figure(figsize=(12,6))

_ = sns.kdeplot(data=df, x='avg_power',linewidth=3)
_ = plt.grid()
_ = plt.xlabel('Strava Avg. Power (Watts)' ,fontsize=16)
_ = plt.ylabel('Density' ,fontsize=16)
_ = plt.title('Strava Estimated Avg. Power' ,fontsize=20)

# %%
# Plot the Distributions of Average Powers for Strava
fig = plt.figure(figsize=(12,6))

_ = sns.kdeplot(data=df, x='ride_avg_power',linewidth=3)
_ = plt.grid()
_ = plt.xlabel('ETL Avg. Power (Watts)' ,fontsize=16)
_ = plt.ylabel('Density' ,fontsize=16)
_ = plt.title('ETL Estimated Avg. Power' ,fontsize=20)

# %%
# Plot the Distributions of Average Powers for Strava
fig = plt.figure(figsize=(12,6))

_ = sns.kdeplot(data=df, x='avg_power', hue='simple_exertion', linewidth=3)
_ = plt.grid()
_ = plt.xlabel('Strava Avg. Power (Watts)' ,fontsize=16)
_ = plt.ylabel('Density' ,fontsize=16)
_ = plt.title('Strava Estimated Avg. Power' ,fontsize=20)

# %%
# Plot the Distributions of Average Powers for Strava
fig = plt.figure(figsize=(12,6))

_ = sns.kdeplot(data=df, x='ride_avg_power', hue='simple_exertion', linewidth=3)
_ = plt.grid()
_ = plt.xlabel('ETL Avg. Power (Watts)' ,fontsize=16)
_ = plt.ylabel('Density' ,fontsize=16)
_ = plt.title('ETL Estimated Avg. Power' ,fontsize=20)

# %%
# KEEP BOTH POWER COLUMNS

# %% [markdown]
# # Work

# %%
df['ride_work'] = (1.0/1000) * df['ride_avg_power'] * df['elapsed_time'] # kiloJoules

# %%
compare_columns(df, 'Work Performed Comparison', strava_col='calories', my_etl_col='ride_work')
_ = plt.ylim([0,2000])
_ = plt.xlim([0,2000])
# QUITE A FEW OUTLIERS

# %%
# Based on the comparison, my Work column has fewer nulls
df.drop(['calories'], axis=1, inplace=True)

# %% [markdown]
# # SAVE

# %%
df.head(10)
# Out:
#       ride_id  row_count  segment_count                start_time  \
# 0  2975587283       1352              5 2020-01-02 14:02:58+00:00
# 1  2992935347       1426              5 2020-01-08 13:20:26+00:00
# 2  2994399692       1423              7 2020-01-08 22:08:17+00:00
# 3  3248077156       2580              5 2020-04-02 21:38:02+00:00
# 4  3255473930       6416             12 2020-04-04 17:23:43+00:00
# 5  3286667096       3957             10 2020-04-11 21:08:20+00:00
# 6  3290080609       3418             16 2020-04-12 14:28:14+00:00
# 7  3294902966       1860              9 2020-04-13 18:10:15+00:00
# 8  3299844988       2173             10 2020-04-14 21:25:18+00:00
# 9  3309212141       2131              5 2020-04-16 20:30:48+00:00
#
#                    end_time  elapsed_time  moving_time  elapsed_distance  \
# 0 2020-01-02 14:29:32+00:00          1642         1411          5.266647
# 1 2020-01-08 13:49:06+00:00          1728         1472          5.167961
# ...

# %%
# Check the Null space
fig = plt.figure(figsize=(12,6))

_ = sns.heatmap(df.isna())

# %%
df.shape
# Out:
# (218, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 218 entries, 0 to 217
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ride_id                    218 non-null    int64
#  1   row_count                  218 non-null    int64
#  2   segment_count              218 non-null    int64
#  3   start_time                 218 non-null    datetime64[ns, UTC]
#  4   end_time                   218 non-null    datetime64[ns, UTC]
#  5   elapsed_time               218 non-null    int64
#  6   moving_time                218 non-null    int64
#  7   elapsed_distance           218 non-null    float64
#  8   elapsed_ascent             218 non-null    float64
#  9   elapsed_descent            218 non-null    float64
#  10  max_speed                  218 non-null    float64
#  11  avg_speed                  218 non-null    float64
#  12  ride_cruise_speed          218 non-null    float64
# ...

# %%
df['simple_exertion'].value_counts()
# Out:
# NORMAL    104
# HARD       49
# EASY       27
# Name: simple_exertion, dtype: int64

# %%
df.to_csv(file_paths['out'], index=False)
